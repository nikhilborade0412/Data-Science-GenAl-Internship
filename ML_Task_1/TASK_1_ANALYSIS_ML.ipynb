# %% [markdown]
# ## Importing the necessary Libraries.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading the dataset.

# %%
df=pd.read_csv(r"scores_data.csv")

# %%
df
# Out:
#          Batch  User_ID     Score
# 0    AI_ELITE_7  uid_149       6 / 7
# 1    AI_ELITE_7  uid_148       6 / 7
# 2    AI_ELITE_7  uid_147       7 / 7
# 3    AI_ELITE_7  uid_146       7 / 7
# 4    AI_ELITE_7  uid_145       4 / 7
# ..          ...      ...         ...
# 144  AI_ELITE_4    uid_5       4 / 7
# 145  AI_ELITE_4    uid_4       4 / 7
# 146  AI_ELITE_4    uid_3       4 / 7
# 147  AI_ELITE_4    uid_2       3 / 7
# 148  AI_ELITE_4    uid_1       2 / 7
#
# [149 rows x 3 columns]

# %% [markdown]
# ## Checking for Shape

# %%
df.shape
# Out:
# (149, 3)

# %% [markdown]
# ####  Observation
# - The shape output tells us the **number of rows and columns**, helping understand dataset size.
# - This confirms whether the dataset is suitable for meaningful analysis.

# %% [markdown]
# ## Checking for info.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Batch        149 non-null    object
#  1   User_ID      149 non-null    object
#  2      Score     149 non-null    object
# dtypes: object(3)
# memory usage: 3.6+ KB

# %% [markdown]
# ####  Observation
# - `df.info()` shows **data types and non-null counts**.
# - No major missing values indicate good data quality for analysis.

# %% [markdown]
# ## Checking for Statistical Description.

# %%
df.describe()
# Out:
#             Batch  User_ID     Score
# count          149      149         149
# unique           3      149           8
# top     AI_ELITE_7  uid_149       4 / 7
# freq            53        1          40

# %% [markdown]
# ####  Observation
# - Summary statistics help identify **mean, spread, and outliers**.
# - Score distribution appears reasonable without extreme anomalies.

# %% [markdown]
# ## Checking for Missing/Null values.

# %%
df.isnull().sum()
# Out:
# Batch          0
# User_ID        0
#    Score       0
# dtype: int64

# %% [markdown]
# ####  Observation
# - Missing value check confirms **data completeness**.
# - Since missing values are minimal or zero, no imputation is required.

# %% [markdown]
# ## Checking the columns present in the dataset.

# %%
df.columns
# Out:
# Index(['Batch', 'User_ID', 'Score'], dtype='object')

# %%
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['Batch', 'User_ID', 'Score'], dtype='object')

# %%
df["Batch"].unique()
# Out:
# array(['AI_ELITE_7', 'AI_ELITE_6', 'AI_ELITE_4'], dtype=object)

# %%
df["Score_Obtained"] = df["Score"].str.split("/").str[0].astype(int)
df["Score_Total"] = df["Score"].str.split("/").str[1].astype(int)
df["Score_Percentage"] = (df["Score_Obtained"] / df["Score_Total"]) * 100

# %%
df.groupby("Batch")["Score_Obtained"].describe()
# Out:
#             count      mean       std  min  25%  50%   75%  max
# Batch
# AI_ELITE_4   48.0  3.791667  1.443376  0.0  3.0  4.0  4.25  7.0
# AI_ELITE_6   48.0  4.229167  1.640441  0.0  3.0  4.0  5.00  7.0
# AI_ELITE_7   53.0  5.056604  1.446682  2.0  4.0  5.0  6.00  7.0

# %% [markdown]
# **AI_ELITE_7 is the top-performing batch, showing higher average scores and no extremely weak performers.**
#
# **AI_ELITE_6 performs moderately, with both high and low performers, showing mixed ability.**
#
# **AI_ELITE_4 has the lowest performance, with many students scoring below average and a number of very weak performers**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

avg_scores = df.groupby("Batch")["Score_Obtained"].mean().reset_index()
sns.barplot(data=avg_scores, x="Batch", y="Score_Obtained")
plt.title("Average Score per Batch")
plt.show()

# %% [markdown]
# ###  Observation
# - Bar plot compares **average scores by batch**.
# - Higher bars clearly highlight top-performing batches.

# %% [markdown]
# **AI_ELITE_7 is the top-performing batch, showing higher average scores and no extremely weak performers.**
#
# **AI_ELITE_6 performs moderately, with both high and low performers, showing mixed ability.**
#
# **AI_ELITE_4 has the lowest performance, with many students scoring below average and a number of very weak performers**

# %%
sns.boxplot(data=df, x="Batch", y="Score_Obtained")
plt.title("Score Distribution per Batch")
plt.show()

# %% [markdown]
# ###  Observation
# - Boxplot shows **score distribution and variability** across batches.
# - AI_ELITE_7 has a higher median score with less spread, indicating consistency.

# %%
sns.countplot(data=df, x="Score_Obtained", hue="Batch")
plt.title("Score Frequency per Batch")
plt.show()

# %% [markdown]
# ###  Observation
# - Countplot reveals **frequency of scores per batch**.
# - Certain batches dominate higher score ranges, indicating better performance.

# %%
print("Average Score by Batch")
print(df.groupby("Batch")["Score_Obtained"].mean())
# Out:
# Average Score by Batch
# Batch
# AI_ELITE_4    3.791667
# AI_ELITE_6    4.229167
# AI_ELITE_7    5.056604
# Name: Score_Obtained, dtype: float64

# %%
print("Median Score by Batch")
print(df.groupby("Batch")["Score_Obtained"].median())
# Out:
# Median Score by Batch
# Batch
# AI_ELITE_4    4.0
# AI_ELITE_6    4.0
# AI_ELITE_7    5.0
# Name: Score_Obtained, dtype: float64

# %%
print("Score Consistency (Std Dev) by Batch")
print(df.groupby("Batch")["Score_Obtained"].std())
# Out:
# Score Consistency (Std Dev) by Batch
# Batch
# AI_ELITE_4    1.443376
# AI_ELITE_6    1.640441
# AI_ELITE_7    1.446682
# Name: Score_Obtained, dtype: float64

# %%
bivariate_perf = df.groupby("Batch")["Score_Obtained"].agg(
    high_performers = lambda x: (x >= 6).sum(),
    moderate = lambda x: ((x >= 4) & (x < 6)).sum(),
    low_performers = lambda x: (x <= 3).sum()
)

print(bivariate_perf)
# Out:
#             high_performers  moderate  low_performers
# Batch
# AI_ELITE_4                4        27              17
# AI_ELITE_6                9        24              15
# AI_ELITE_7               23        21               9

# %%
print(df.groupby("Batch")["Score_Percentage"].describe())
# Out:
#             count       mean        std        min        25%        50%  \
# Batch
# AI_ELITE_4   48.0  54.166667  20.619652   0.000000  42.857143  57.142857
# AI_ELITE_6   48.0  60.416667  23.434869   0.000000  42.857143  57.142857
# AI_ELITE_7   53.0  72.237197  20.666883  28.571429  57.142857  71.428571
#
#                   75%    max
# Batch
# AI_ELITE_4  60.714286  100.0
# AI_ELITE_6  71.428571  100.0
# AI_ELITE_7  85.714286  100.0

# %%
summary = df.groupby("Batch").agg(
    mean_score = ("Score_Obtained","mean"),
    median_score = ("Score_Obtained","median"),
    std_dev = ("Score_Obtained","std"),
    min_score = ("Score_Obtained","min"),
    max_score = ("Score_Obtained","max"),
    count = ("User_ID","count")
)

print(summary)
# Out:
#             mean_score  median_score   std_dev  min_score  max_score  count
# Batch
# AI_ELITE_4    3.791667           4.0  1.443376          0          7     48
# AI_ELITE_6    4.229167           4.0  1.640441          0          7     48
# AI_ELITE_7    5.056604           5.0  1.446682          2          7     53

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
plt.figure(figsize=(12,6))

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df, x="Batch", y="Score_Percentage", hue = "Batch", palette="rocket")
plt.title("Average Percentage Score Per Batch", fontsize=14)
plt.xlabel("Batch")
plt.ylabel("Average Percentage")
plt.show()

# %% [markdown]
# ###  Observation
# - Bar plot compares **average scores by batch**.
# - Higher bars clearly highlight top-performing batches.

# %%
plt.figure(figsize=(9,5))
sns.kdeplot(data=df, x="Score_Obtained", hue="Batch", fill=True)
plt.title("Score Density Curve", fontsize=14)
plt.xlabel("Score Obtained")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# ###  Observation
# - KDE plot shows **score distribution density**.
# - Top batches have curves shifted right, indicating higher overall scores.

# %% [markdown]
# ## Overall Observations & Insights
#
# - **AI_ELITE_7** batch shows the highest average and median scores, indicating strong performance.
# - Score distribution across batches suggests some variability, with certain batches being more consistent.
# - No major missing value issues were observed in the dataset.
# - KDE and boxplots indicate that top batches not only score higher but also show tighter score spread.
# - These insights can help identify best-performing batches and areas needing improvement.
